# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
import os
path = '/content/drive/My Drive'
sys.path.append(path)
os.chdir(path)
# %cd Neural Network & Deep Learning
# Out:
# /content/drive/My Drive/Neural Network & Deep Learning

# %%
import torch
torch.version.cuda
# Out:
# '11.1'

# %%
# !export LD_LIBRARY_PATH="/usr/local/cuda-11.1/lib64:$LD_LIBRARY_PATH"

# %%
# !git clone https://github.com/qiaoguan/Person-reid-GAN-pytorch.git

# %%
# same
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
# update 1
# !conda install -q -y --prefix /usr/local python=3.7 ujson
# update 2
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages')
# # test it
# !pip install ujson
# import ujson
# print(ujson.dumps({1:2}))
# Out:
# --2021-12-18 21:32:31--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
# ...

# %%
# %cd Person-reid-GAN-pytorch/
# Out:
# /content/drive/My Drive/Neural Network & Deep Learning/Person-reid-GAN-pytorch

# %%
# %cd DCGAN-tensorflow/
# Out:
# /content/drive/My Drive/Neural Network & Deep Learning/Person-reid-GAN-pytorch/DCGAN-tensorflow

# %%
# !conda env create -f dcgan.yml
# !source activate dcgan
# Out:
# ...
# done
# done
#
# ...
# readline-6.2         | 713 KB    | : 100% 1.0/1 [00:00<00:00,  2.60it/s]
# pyparsing-3.0.6      | 79 KB     | : 100% 1.0/1 [00:00<00:00, 16.02it/s]
# openjpeg-2.4.0       | 444 KB    | : 100% 1.0/1 [00:00<00:00,  7.58it/s]
# sqlite-3.13.0        | 4.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.63s/it]
# libdeflate-1.8       | 67 KB     | : 100% 1.0/1 [00:00<00:00, 22.19it/s]
# protobuf-3.18.0      | 344 KB    | : 100% 1.0/1 [00:00<00:00,  6.35it/s]
# libblas-3.9.0        | 11 KB     | : 100% 1.0/1 [00:00<00:00, 29.87it/s]
# cycler-0.11.0        | 10 KB     | : 100% 1.0/1 [00:00<00:00, 22.31it/s]
# lcms2-2.12           | 443 KB    | : 100% 1.0/1 [00:00<00:00, 10.40it/s]
# libgcc-ng-11.2.0     | 887 KB    | : 100% 1.0/1 [00:00<00:00,  6.33it/s]
# lz4-c-1.9.3          | 179 KB    | : 100% 1.0/1 [00:00<00:00, 13.97it/s]
# python_abi-3.6       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 26.45it/s]
# imageio-2.13.1       | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
# ...

# %%
# !pip install scipy==1.2.1
# Out:
# ...
#      |████████████████████████████████| 24.8 MB 59.6 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 55.4 MB/s
# ...

# %%
# !pip install Pillow==6.0.0
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 13.9 MB/s
# ...

# %%
# !pip install imageio
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 12.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 50.3 MB/s
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 6.0.0
#     Uninstalling Pillow-6.0.0:
#       Successfully uninstalled Pillow-6.0.0
# ...

# %%
# !pip install -U setuptools
# Out:
# ...
#      |████████████████████████████████| 952 kB 12.6 MB/s
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 45.2.0.post20200210
#     Uninstalling setuptools-45.2.0.post20200210:
#       Successfully uninstalled setuptools-45.2.0.post20200210
# ...

# %%
# !pip install scikit-image
# Out:
# ...
#      |████████████████████████████████| 13.3 MB 14.4 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 43.4 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 178 kB 65.7 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 65.8 MB/s
# ...
#      |████████████████████████████████| 6.1 MB 54.7 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.7 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.2.1
#     Uninstalling scipy-1.2.1:
#       Successfully uninstalled scipy-1.2.1
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Neural Network & Deep Learning/Person-reid-GAN-pytorch

# %%
# !python prepare.py
# Out:
# Traceback (most recent call last):
#   File "prepare.py", line 47, in <module>
#     #         copyfile(src_path, dst_path + '/' + name)
#   File "/usr/lib/python3.7/shutil.py", line 121, in copyfile
#     with open(dst, 'wb') as fdst:
# KeyboardInterrupt

# %%
# !python changeIndex.py

# %%
# !pip install tensorflow-gpu==1.14.0
# Out:
# ...
#      |████████████████████████████████| 377.1 MB 9.1 kB/s
# ...
#      |████████████████████████████████| 57 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 488 kB 69.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 64.7 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 38.6 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 126 kB 55.2 MB/s
# ...
#      |████████████████████████████████| 97 kB 9.0 MB/s
# ...
#      |████████████████████████████████| 288 kB 69.5 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 55.4 MB/s
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=e72631cad42251b78a982ba1d674df77c739a31828902cfba1e7dd56f6c62bfa
# ...

# %%
# %cd DCGAN-tensorflow/
# Out:
# /content/drive/MyDrive/Neural Network & Deep Learning/Person-reid-GAN-pytorch/DCGAN-tensorflow

# %%
# !python main.py --dataset market --options 1 --train True
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Epoch: [ 1] [ 148/ 202] time: 564.9377, d_loss: 1.46299279, g_loss: 0.41018116
# Epoch: [ 1] [ 149/ 202] time: 565.7536, d_loss: 1.57210410, g_loss: 0.55297554
# Epoch: [ 1] [ 150/ 202] time: 566.5603, d_loss: 1.55527377, g_loss: 0.38625944
# Epoch: [ 1] [ 151/ 202] time: 567.3729, d_loss: 1.75434959, g_loss: 0.31443089
# Epoch: [ 1] [ 152/ 202] time: 568.1720, d_loss: 1.59130490, g_loss: 0.43903261
# Epoch: [ 1] [ 153/ 202] time: 568.9823, d_loss: 2.25420976, g_loss: 0.17817728
# Epoch: [ 1] [ 154/ 202] time: 569.7939, d_loss: 1.69649494, g_loss: 0.63189602
# Epoch: [ 1] [ 155/ 202] time: 570.5952, d_loss: 1.97646928, g_loss: 0.20335485
# Epoch: [ 1] [ 156/ 202] time: 571.4797, d_loss: 1.76407528, g_loss: 0.63916433
# Epoch: [ 1] [ 157/ 202] time: 572.2704, d_loss: 2.02012157, g_loss: 0.24282369
# Epoch: [ 1] [ 158/ 202] time: 573.0596, d_loss: 1.87204516, g_loss: 0.85015523
# ...

# %%
# !python main.py --dataset market --options 5  --output_path gen_market  --sample_size 1000
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python resizeImage.py
